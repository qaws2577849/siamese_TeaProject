# %% [markdown]
# <a href="https://colab.research.google.com/github/qaws2577849/siamese_TeaProject/blob/main/%E5%BD%B1%E5%83%8F%E5%88%87%E5%89%B2%E7%85%A7%E7%89%87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import glob

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
video_path = '/content/drive/MyDrive/第3次拍攝影片/威叔鐵觀音紅茶_3_C.mp4'
output_folder = '/content/drive/MyDrive/siamese_1/testing_set/威叔鐵觀音紅茶_C/'

# #if os.path.isdir(output_folder):
#     print("Delete old result folder: {}".format(output_folder))
#     os.system("rm -rf {}".format(output_folder))
# os.system("mkdir {}".format(output_folder))
# print("create folder: {}".format(output_folder))

vc = cv2.VideoCapture(video_path)
fps = vc.get(cv2.CAP_PROP_FPS)
frame_count = int(vc.get(cv2.CAP_PROP_FRAME_COUNT))
print(frame_count)
video = []

frame_interval = 1  # 提取每2帧

for idx in range(0, frame_count, frame_interval):
    vc.set(1, idx)
    ret, frame = vc.read()
    height, width, layers = frame.shape
    size = (width, height)

    if frame is not None:
        file_name = '{}{:08d}.jpg'.format(output_folder,idx+30000000)
        cv2.imwrite(file_name, frame)
        print(file_name)
    print("\rprocess: {}/{}".format(idx+1 , frame_count), end = '')
vc.release()
# Out:
# 912
# /content/drive/MyDrive/siamese_1/testing_set/威叔鐵觀音紅茶_C/30000000.jpg
# process: 1/912/content/drive/MyDrive/siamese_1/testing_set/威叔鐵觀音紅茶_C/30000001.jpg
# process: 2/912/content/drive/MyDrive/siamese_1/testing_set/威叔鐵觀音紅茶_C/30000002.jpg
# process: 3/912/content/drive/MyDrive/siamese_1/testing_set/威叔鐵觀音紅茶_C/30000003.jpg
# process: 4/912/content/drive/MyDrive/siamese_1/testing_set/威叔鐵觀音紅茶_C/30000004.jpg
# process: 5/912/content/drive/MyDrive/siamese_1/testing_set/威叔鐵觀音紅茶_C/30000005.jpg
# process: 6/912/content/drive/MyDrive/siamese_1/testing_set/威叔鐵觀音紅茶_C/30000006.jpg
# process: 7/912/content/drive/MyDrive/siamese_1/testing_set/威叔鐵觀音紅茶_C/30000007.jpg
# process: 8/912/content/drive/MyDrive/siamese_1/testing_set/威叔鐵觀音紅茶_C/30000008.jpg
# process: 9/912/content/drive/MyDrive/siamese_1/testing_set/威叔鐵觀音紅茶_C/30000009.jpg
# process: 10/912/content/drive/MyDrive/siamese_1/testing_set/威叔鐵觀音紅茶_C/30000010.jpg
# ...
